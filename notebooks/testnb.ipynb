# %%
import pandas as pd

# %%
# Load data from PDF: extract text and tables
import pdfplumber
from pathlib import Path

pdf_path = Path('data/Test.pdf')
assert pdf_path.exists(), f"PDF not found at {pdf_path.resolve()}"

texts = []
tables = []
with pdfplumber.open(pdf_path) as pdf:
    for page in pdf.pages:
        # Extract text
        page_text = page.extract_text() or ''
        if page_text.strip():
            texts.append(page_text)
        # Extract tables
        page_tables = page.extract_tables()
        for t in page_tables:
            tables.append(t)

# Show first 500 chars of text
print('\n--- TEXT PREVIEW ---\n')
print(('\n'.join(texts))[:500])

text = '\n'.join(texts)
# Out:
# --- TEXT PREVIEW ---
#
# L E I S T U N G S V E R Z E I C H N I S
# Projekt: DKFZ, Heidelberg - FER
# Forschungs- u. Entwicklungszentrum f. Radiopharmazeutische Chemie
# Bauherr:
# Gewerk: Labortechnik
# Fachplanung: dr. heinekamp Labor- und Institutsplanung GmbH Gaußstr. 12 85757
# Karlsfeld
# Aufgestellt: 12 Februar 2025
# Inhaltsverzeichnis
# DKFZ, Heidelberg - FER
# Seite
# Vorbemerkungen Gewerk Labortechnik
# Allgemeine Vorbemerkungen VOB/C 1
# Zusätzliche Technische Vertragsbedingungen nach BNB 15
# Baubeschreibung Labortechnik 19
# Ergänzung d

# %%
print(len(texts))
# Out:
# 533

# %% [markdown]
# ## Extract the Vorbemerkungen

# %%
json_schema = """
{
  "type": "object",
  "properties": {
    "vorbemerkungen": {
      "type": "array",
      "items": {
        "type": "object",
        "properties": {
          "title": { "type": "string" },
          "page_from": { "type": ["integer", "null"] },
          "page_to": { "type": ["integer", "null"] },
          "text": { "type": "string" }
        },
        "required": ["title", "page_from", "page_to", "text"]
      }
    }
  },
  "required": ["vorbemerkungen"]
}
"""

# %%
prompt = """
Task: Extract the Vorbemerkungen from the German LV-Liste text.
Output: Return only JSON that matches the schema below—no prose.

Input format: You will receive raw text from a PDF (German), possibly with page numbers.

Your job:
1.	Find the Vorbemerkungen.
2.	Extract the title, page range, and text for each Vorbemerkung.
3.	Normalize trivial whitespace; keep German umlauts.

Return only JSON matching the schema below.
"""

prompt_with_json_schema = f"""
{prompt}

JSON schema (validate strictly)

{json_schema}
"""

prompt_with_json_and_text = f"""
{prompt_with_json_schema}

Input:
{text}
"""

# %%
# Call OpenAI API
from openai import OpenAI
import os

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

response = client.responses.create(
    model="gpt-5",
    input=prompt_with_json_and_text
)

print(response.output_text)
# Out:
# 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
# {
#   "vorbemerkungen": [
#     {
#       "title": "Allgemeine Vorbemerkungen VOB/C",
#       "page_from": 1,
#       "page_to": 14,
. Vorgefertigte Bauelemente mit Herstellerangaben deklarieren. Einbau erst nach Freigabe durch Baustoffberater (Freigabetabelle). Hölzer zusätzlich in Anlage 03 „Holzdeklaration“ (Produkt, Hersteller, Funktion, Holzart, Herkunft, Zertifikate). Abweichungen von Ausschreibung sind kostenneutral zu ersetzen. Anlagen: Anlage 01 Materialanforderungen; Anlage 02 Produktdeklaration; Anlage 03 Holzdeklaration. Ausnahmen Bei fehlender gleichwertiger Erfüllbarkeit: schriftliche Begründung/Voranmeldung mit Produkt, Verwendung, Menge (keine Ausnahmen aus ästhetischen/Termin-Gründen). Verbindlichkeit Änderungen früh ankündigen und erneut deklarieren; Abweichungen sind kostenneutral auszutauschen. Stichprobenkontrollen (Produkt/Raumluft) vorbehalten. Pflicht zur Weitergabe AN verantwortet Einhaltung durch NU. B – ANFORDERUNGEN AN DIE BAUSTELLE Abfalltrennung Gemäß KrWG; Trennung in mineralische Abfälle, Wertstoffe, gemischte Baustellenabfälle, Problem- und asbesthaltige Abfälle; Schulung zur Vermeidung/Trennung. Lärmschutz Einhaltung BImSchG/AVV Baulärm. Richtwerte tags 65 dB(A), nachts 50 dB(A). Einsatz von Maschinen nach RAL-UZ 53; Abweichungen begründen. Staubschutz Erfassung/Entsorgung an Entstehungsstelle; Absaugtechnik; Feucht-/Nassverfahren; geeignete Abscheider; regelmäßige Wartung/Prüfung; Ausbreitungs- und Ablagerungsvermeidung. Bodenschutz Vermeidung chemischer Kontamination und schädlicher mechanischer Einflüsse; kein Kontakt der Umwelt mit Stoffen R50–R59."
#     },
#     {
#       "title": "Baubeschreibung Labortechnik",
#       "page_from": 19,
#       "page_to": 24,
#       "text": "BAUBESCHREIBUNG Grundstück Die Baustelle befindet sich auf dem Campusgelände „Im Neuenheimer Feld“, Kirschnerstraße 262, 69120 Heidelberg. Der Neubau orientiert sich an den Kanten des bestehenden Zyklotron-Gebäudes und der Flucht des Pathologischen Instituts. Vorhandene Infrastruktur Zyklotron-Gebäude bleibt, Zyklotron außer Betrieb. Nachbarschaft: Pathologie, Präklinische Forschung (DKFZ), Klinik SFB; neue Straßenbahnlinie südlich. Anbindung an unterirdische Verbindungs-/Versorgungsgänge (Ebenen 98/99) zum Hauptgebäude (INF 280), Wirtschaftshof, REZ (INF 223). Konstruktion Stahlbetonskelett, Flachdecken ohne Unterzüge, aussteifende Wände/Kerne. Architektur Nord–Süd-Riegel mit nördlicher/südlicher Erschließungsspange und flexibel bespielbarem Laborbereich; Büro- und Laborgebäude mit GMP-Bereich (aktuelle GMP- und Strahlenschutzanforderungen, Zertifizierung), Synthese-/Radiochemie-, Theranostiklabore; Technikzentrale im 1. OG, Theranostik im 2. OG über Technik; flexible Laborlandschaft (Raster 1,15 m; GMP-Raster 1,25 m). Materialien Sichtbeton, Holz, Glas, Fassadengrün; innen beschichtete Decken/Trockenbau, polierter Estrich, Holz-/Alu-Glas-Trennwände, grüne Beläge; hoher Anspruch an Sichtbeton. BAUBESCHREIBUNG LABORTECHNIK Im EG Reinraumbereich nach GMP (Klasse C, Materialdurchreichen, Lager, Büro, Umkleiden/Schleusen), Qualitätskontrolllabor, Gasflaschenschränke, ca. 590 m². UG: Abfallentsorgung/Abklinglager/Rückstellproben. 2. OG: Theranostik (Radionuklide), Maushaltung, Großgeräte (PET-MR, IGRT). 3. OG: F&E-Labore als flexible Laborzeilen (5–6 m), Grundausstattung Medien/Abzüge/Gefahrstofflagerung; dezentrale LN2-Versorgung (mobiler Tank ~200 l). Leistungsumfang Labortechnik u. a.: – Baugebundene Labormöbel (Tische, Abzüge, Sicherheitsschränke, Medienversorgung), – dezentrale WW-Versorgung (Durchlauferhitzer), – dezentrale Reinstgasversorgung inkl. Gaswarnung, – nichttragende Systemtrennwände (2. OG), – lose Ausstattung (Unterbauten, Rolltische), – Elektronikarbeitstische, – Tierhaltungsequipment (IVC, Wagen), – Lagerausstattung, – dezentrale Flüssigstickstoffversorgung inkl. Sauerstoffmangelüberwachung. Reinraumtechnik separat. Zusätzlicher Koordinationsaufwand (Jour fixe + 4‑wöchentliche Koordinationstermine, Schnittstellenabstimmungen vor/nach Montageplanung). Für GMP: URS als Basisdokument (beigefügt); Hierarchie bei Widersprüchen: URS > Schemata > Pläne > Ausschreibungstexte. Qualifizierung (DQ/IQ/OQ/PQ) durch QM; AN liefert Unterlagen, schafft technische Voraussetzungen, nimmt an Risikoanalyse teil, meldet Änderungen (GMP-Änderungs-/Mängelmanagement). Regelwerke (Auszug): DGUV 213‑850, TRGS 526, ArbStättV, EN 12128, EN 14175, EN 14470, BioStoffV, GenTAufzV, GV-SOLAS, EU-GMP Leitfaden, EN ISO 14644/14698, VDI 2083, EN 15154, FDA 21 CFR, DIN 12918/12915/12916, DIN 1946-7, DIN 25425-1, GefStoffV, StrlSchV/StrlSchG, ChemV, DIN 4102/4103/4109/18168/18202 u. a. Dokumentation Bereichsdoku an Auftraggebervorgaben (Struktur/Nummerierung) anpassen; Kosten in Positionen Dokumentation einkalkulieren. Anlagenkennzeichnungssystem (AKS) verpflichtend für alle Komponenten (Beistellung durch AG). Eintransport siehe Technische Grundlagen. Lagerung: keine bauseitigen Flächen – Lieferung frei Aufstellplatz inkl. Montage/IBN."
#     },
#     {
#       "title": "Ergänzung der Angebotsanforderung",
#       "page_from": 25,
#       "page_to": 25,
#       "text": "Automatische Sortierung Die Ausschreibungsunterlagen wurden automatisch sortiert. Der Bieter hat die Vollständigkeit anhand der Seitenzahlen zu prüfen und fehlende Blätter beim DKFZ anzufordern. Doppelseiten sind auszusortieren und zu vernichten. Textergänzungen der Leistungsbeschreibung (Fabrikat-/technische Angaben etc.) sind zwingend auszufüllen. Fehlende Eintragungen machen das Angebot unvollständig und grundsätzlich nicht wertbar."
#     },
#     {
#       "title": "Weitere Besondere Vertragsbedingungen",
#       "page_from": 25,
#       "page_to": 27,
#       "text": "Anordnung von Stundenlohnarbeiten Stundenlohnarbeiten nur auf ausdrückliche Anweisung des AG/Objektüberwachung (außer Havarie). Kein Anspruch auf im Angebot genannte Stundenkontingente. Einzelbestellungen grundsätzlich vor Ausführung; Ausnahmen (Noteinsätze) nachvollziehbar dokumentieren. Vor Abruf Schätzung durch AN; Änderungen vor Ausführung anmelden/begründen. Verrechnungssatz umfasst alle Aufwendungen (Löhne/NK/Zuschläge/GK/Wagnis/Gewinn). Stundenlohnnachweise arbeitstäglich/wöchentlich zur Unterschrift vorlegen; Anforderungen an Inhalt (Firma, Datum, Mitarbeiter, Ort, Leistung, Zeiten, Pausen, Unterschriften etc.); Unvollständige Nachweise können abgelehnt werden. Bescheinigung ist kein Rechnungsanerkenntnis; Originale verbleiben beim AG; Kopien der abgezeichneten Nachweise der Rechnung beifügen. Koordination und Bauleitung durch den AN Ständig deutschsprachige, fachlich qualifizierte Aufsichtsperson vor Ort. Wöchentliche Bautagesberichte (Leistungen, Personal/Geräte, Ereignisse, Weisungen, Witterung, Prüfungen). AG darf jederzeit begehen; frühe Zustandsfeststellungen; Zutritt zu allen Bereichen; Teilnahme eines weisungsbefugten AN-Mitarbeiters. Schlüsselpersonen nur mit Zustimmung austauschbar. Inbetriebnahme in enger Zusammenarbeit mit dem Gebäude. Nachabnahmen bei unzureichender Mängelbeseitigung auf Kosten des AN. Baustellenbesprechungen Wöchentlich; Teilnahme eines bevollmächtigten Vertreters. Verkehrssprache Deutsch; Baustellenchef und Vertreter beherrschen Deutsch in Wort und Schrift."
#     },
#     {
#       "title": "Technische Grundlagen",
#       "page_from": 28,
#       "page_to": 34,
#       "text": "Grundlage des Leistungsverzeichnisses Einrichtungszeichnungen des Verfassers; Grundrisspläne 1:50 beim AG einsehbar. Montage- und Ausführungszeiten Terminplan 1 Woche nach Beauftragung; 3 Wochen Prüfzeit für Unterlagen. Labormöbelsystem Rastermaß 30 cm, modular; Angebotspreise beinhalten interne Verrohrung/Verkabelung und bauseitige Anschlüsse betriebsfertig. Deckendurchbiegungen (bis 70 Jahre) gemäß Anlage berücksichtigen. Arbeitstischanlagen/Laborpositionen Einheitliche Höhe (ca. 275 cm), im EG Verblendung bis 300 cm; Positionstiefen: einseitig max. 90 cm (Arbeitsfläche je Seite ≥ 80 cm), doppelseitig max. 180 cm; flächenbündige Tiefenabstimmung (Korpus, Unterbau, Gefahrstoffunterbau, Medienblende, Tischgestell). Gerüstbauweise; Unterbauten (außer Becken) fahrbar; Medienversorgung über Energiezellen/Deckenversorgung/Wandkanäle. Wandhängeregale/-schränke in Ständer einhängbar und zusätzlich an Wand arretiert. Tragfähigkeit/Qualitätsnachweise beizulegen; Rastermaße 60/90/120/150 cm verbindlich. Farbgebung gemäß Farbkonzept (RAL 7035 nah, differenziert je Bauteil). Beständigkeit gegen chemische/physikalische/mechanische Beanspruchung sowie Desinfektionsmittel. Materialien Holz/Kunststoff oder gleichwertig; Stahlblechausführung nur bei Gleichwertigkeitsnachweis (Abzüge, Medienversorgungseinheiten, Korpora etc.); Stahlblech: min
ten (AN Reinraum). Medienanschlusspunkte u. a.: KW DN15, Notdusche DN20, Kühlwasser DN25, VE DN15, Druckluft DN10, Abfluss PE‑HD DN70 (Details im Text). Dezentrale Medien Gasflaschenschränke (AN Labortechnik); Reinraum: Verrohrung ab 2,8 m in Zwischendecke zu Paneelen durch AN Reinraum; Labor: komplette Verrohrung inkl. Absperrventile durch AN Labor. Elektro und MSR/GA Zuleitung je Laborzeile AV-Netz frei Kabelende (NYM 5x10 mm²) auf

# %% [markdown]
# ## Extract the Product Groups

# %%
group_extraction_prompt = """
Task: Extract the Product Groups from the German LV-Liste text.
Output: Return only JSON that matches the schema below—no prose.

Input format: You will receive raw text from a PDF (German), possibly with page numbers.

Your job:
1.	Find the Product Groups.
2.	Extract the title, page range, and product group number.
3.	Normalize trivial whitespace; keep German umlauts.

Return only JSON matching the schema below.

{
  "type": "object",
  "properties": {
    "document_title": { "type": ["string", "null"] },
    "groups": {
      "type": "array",
      "items": {
        "type": "object",
        "properties": {
          "group_no": { "type": ["string", "null"] },
          "title": { "type": "string" },
          "page_from": { "type": ["integer", "null"] },
          "page_to": { "type": ["integer", "null"] },
        },
        "required": ["title", "page_from", "page_to"]
      }
    }
  },
  "required": ["groups"]
}
"""

group_extraction_prompt = f"""
{group_extraction_prompt}

Input:
{text}
"""

# %%
# Call OpenAI API

group_extraction_response = client.responses.create(
    model="gpt-5",
    input=group_extraction_prompt
)

print(group_extraction_response.output_text)
# Out:
# {
#   "document_title": "DKFZ, Heidelberg - FER – Gewerk Labortechnik",
#   "groups": [
#     { "group_no": "01.01", "title": "Trennwandsystem", "page_from": 45, "page_to": 45 },
#     { "group_no": "01.02", "title": "Abzüge", "page_from": 46, "page_to": 79 },
#     { "group_no": "01.03", "title": "Lüftungsbauelemente", "page_from": 80, "page_to": 82 },
#     { "group_no": "01.04", "title": "Abzugshauben", "page_from": 83, "page_to": 83 },
#     { "group_no": "01.05", "title": "Lüftungsgerät", "page_from": 84, "page_to": 84 },
#     { "group_no": "01.06", "title": "Medienversorgungseinheiten", "page_from": 85, "page_to": 123 },
#     { "group_no": "01.07", "title": "Elektroinstallation", "page_from": 124, "page_to": 126 },
#     { "group_no": "01.08", "title": "Elektrotechnische Sonderbauteile", "page_from": 127, "page_to": 137 },
#     { "group_no": "01.09", "title": "Labormöbelverblendungen", "page_from": 138, "page_to": 143 },
#     { "group_no": "01.10", "title": "Handwaschbeckenelement", "page_from": 144, "page_to": 147 },
#     { "group_no": "01.11", "title": "Labortische", "page_from": 148, "page_to": 166 },
#     { "group_no": "01.12", "title": "Becken", "page_from": 167, "page_to": 168 },
#     { "group_no": "01.13", "title": "Ausrüstung Tierbereich", "page_from": 169, "page_to": 175 },
#     { "group_no": "01.14", "title": "Unterbauten", "page_from": 176, "page_to": 184 },
#     { "group_no": "01.15", "title": "Wandhängeschränke, -regale und -ablagen", "page_from": 185, "page_to": 189 },
#     { "group_no": "01.16", "title": "Spezialschränke und -regale", "page_from": 190, "page_to": 214 },
#     { "group_no": "01.17", "title": "Werkstatteinrichtung", "page_from": 215, "page_to": 217 },
#     { "group_no": "01.18", "title": "Laboreinbaugeräte und Zubehör", "page_from": 218, "page_to": 231 },
#     { "group_no": "01.19", "title": "Sicherheitswerkbänke", "page_from": 232, "page_to": 241 },
#     { "group_no": "01.20", "title": "Isotopenmeßtechnik", "page_from": 242, "page_to": 243 },
#     { "group_no": "01.21", "title": "Stationsdruckminderer", "page_from": 244, "page_to": 249 },
#     { "group_no": "01.22", "title": "Flüssigstickstoffanlagen", "page_from": 250, "page_to": 252 },
#     { "group_no": "01.23", "title": "Rohrleitungssystem", "page_from": 253, "page_to": 260 },
#     { "group_no": "01.24", "title": "Sicherheitsschränke für Gasflaschen", "page_from": 261, "page_to": 264 },
#     { "group_no": "01.25", "title": "Gaswarn- Gasmangelanlage", "page_from": 265, "page_to": 269 },
#     { "group_no": "01.26", "title": "Sonderinstallation", "page_from": 270, "page_to": 270 },
#     { "group_no": "01.27", "title": "Sonstige Leistungen", "page_from": 271, "page_to": 271 },
#     { "group_no": "01.28", "title": "Stundenlohnarbeiten", "page_from": 272, "page_to": 273 },
#     { "group_no": "01.29", "title": "Dokumentation", "page_from": 274, "page_to": 274 },
#     { "group_no": "01.30", "title": "Preiszusammenstellung Gewerk Labortechnik Kapitel Labortechnik", "page_from": 275, "page_to": 278 },
#     { "group_no": "02.01", "title": "Abzüge", "page_from": 279, "page_to": 297 },
#     { "group_no": "02.02", "title": "Lüftungsbauelemente", "page_from": 298, "page_to": 299 },
#     { "group_no": "02.03", "title": "Abzugshauben", "page_from": 300, "page_to": 300 },
#     { "group_no": "02.04", "title": "Medienversorgungseinheiten", "page_from": 301, "page_to": 317 },
#     { "group_no": "02.05", "title": "Elektroinstallation", "page_from": 318, "page_to": 320 },
#     { "group_no": "02.06", "title": "Elektrotechnische Sonderbauteile", "page_from": 321, "page_to": 325 },
#     { "group_no": "02.07", "title": "Labormöbelverblendungen", "page_from": 326, "page_to": 328 },
#     { "group_no": "02.08", "title": "Handwaschbeckenelement", "page_from": 329, "page_to": 331 },
#     { "group_no": "02.09", "title": "Labortische", "page_from": 332, "page_to": 347 },
#     { "group_no": "02.10", "title": "Becken", "page_from": 348, "page_to": 349 },
#     { "group_no": "02.11", "title": "Unterbauten", "page_from": 350, "page_to": 358 },
#     { "group_no": "02.12", "title": "Wandhängeschränke, -regale und -ablagen", "page_from": 359, "page_to": 362 },
#     { "group_no": "02.13", "title": "Spezialschränke und -regale", "page_from": 363, "page_to": 386 },
#     { "group_no": "02.14", "title": "Laboreinbaugeräte und Zubehör", "page_from": 387, "page_to": 393 },
#     { "group_no": "02.15", "title": "Spezialgeräte", "page_from": 394, "page_to": 394 },
#     { "group_no": "02.16", "title": "Sicherheitswerkbänke", "page_from": 395, "page_to": 396 },
#     { "group_no": "02.17", "title": "Isotopenmeßtechnik", "page_from": 397, "page_to": 398 },
#     { "group_no": "02.18", "title": "Stationsdruckminderer", "page_from": 399, "page_to": 404 },
#     { "group_no": "02.19", "title": "Flüssigstickstoffanlagen", "page_from": 405, "page_to": 407 },
#     { "group_no": "02.20", "title": "Rohrleitungssystem", "page_from": 408, "page_to": 411 },
#     { "group_no": "02.21", "title": "Sicherheitsschränke für Gasflaschen", "page_from": 412, "page_to": 415 },
#     { "group_no": "02.22", "title": "Gaswarn- Gasmangelanlage", "page_from": 416, "page_to": 419 },
#     { "group_no": "02.23", "title": "Sonstige Leistungen", "page_from": 420, "page_to": 420 },
#     { "group_no": "02.24", "title": "Stundenlohnarbeiten", "page_from": 421, "page_to": 422 },
#     { "group_no": "02.25", "title": "Dokumentation", "page_from": 423, "page_to": 423 },
#     { "group_no": "02.26", "title": "Qualifizierung", "page_from": 424, "page_to": 424 },
#     { "group_no": "02.27", "title": "Preiszusammenstellung Gewerk Labortechnik Kapitel Labortechnik für GMP-Bereich", "page_from": 425, "page_to": 426 }
#   ]
# }

# %% [markdown]
# ## Save the json Files

# %%
with open('data/product_groups.json', 'w') as f:
    f.write(group_extraction_response.output_text)
with open('data/vorbemerkungen.json', 'w') as f:
    f.write(response.output_text)

# %% [markdown]
# ## Get the page offset with a regex

# %%
## Chec if text includes the word "Seite" followed by a colon immediately and followed by a number. The number may be preceded by a space.

import re

for i in range(len(texts)):
    if re.search(r'Seite\s*:\s*\d+', texts[i]):
        page_offset = i
        print(i)
        break
# Out:
# 21

# %% [markdown]
# ## Extract Product Variants

# %%
def get_product_variants_prompt(prod_group_nr, prod_group_title):
    json_schema = """
    {
    "type": "object",
    "properties": {
        "variants": {
            "type": "array",
            "items": {
                "type": "object",
                "properties": {
                    "variant_no": { "type": ["string", "null"] },
                    "title": { "type": "string" },
                    "page_from": { "type": ["integer", "null"] },
                    "page_to": { "type": ["integer", "null"] },
                    "text": { "type": "string" }
                    },
                "required": ["title", "page_from", "page_to"^]
            }
        }
    }
    """
    return f"""
    Task: Extract the Product Variants for the product group {prod_group_nr} {prod_group_title} from the German LV-Liste text.
    Output: Return only JSON that matches the schema below—no prose.

    Input format: You will receive raw text from a PDF (German) with the necessary information.

    Your job:
    1.	Find the Product Variants.
    2.	Extract the title, page range, product variant number, and text. The title (kurztext) is a short description of the product variant and the text is the product variant description (langtext).
    3.	Normalize trivial whitespace; keep German umlauts.

    Return only JSON matching the schema below.

    {json_schema}
    """

def get_product_variants(prod_group_nr, prod_group_title, page_from, page_to, page_offset, texts, client):
    prompt = get_product_variants_prompt(prod_group_nr, prod_group_title)
    pages = texts[page_offset + page_from - 1:page_offset + page_to + 1]
    text = "\n".join(pages)
    input_prompt = prompt + "\n\n" + text
    response = client.responses.create(
        model="gpt-5",
        input=input_prompt
    )
    return response.output_text

# %%
import json

with open('data/product_groups.json', 'r') as f:
    product_groups = json.load(f)

group_1 = product_groups["groups"][1]
print(group_1)
group_1_variants = get_product_variants(group_1["group_no"], group_1["title"], group_1["page_from"], group_1["page_to"], page_offset, texts, client)
print(group_1_variants)
# Out:
# {'group_no': '01.02', 'title': 'Abzüge', 'page_from': 46, 'page_to': 79}
# {
#   "variants": [
#     {
#       "variant_no": "01.02.0001",
#       "title": "Abzug Abfallbehälter 20mm Pb",
#       "page_from": 56,
#       "page_to": 57,
#       "text": "Erweiterte Ausstattung abgeschirmte Abfallbehälter für Radionuklidabzug. Fest eingebauter Abfallbehälter mit 20 mm Bleiabschirmung unterhalb des Abzugs (Abwurfprinzip). Die Abfalleinheit ist statisch unabhängig von dem Abzug untergebaut, damit diese bei Bedarf gegen eine größere Einheit ausgetauscht werden kann. Eine Einschränkung durch Verblendungen darf nicht gegeben sein. Diese müssen zum Ausbau der Abfalleinheit leicht demontierbar sein. Unterbaustahlschrank, mit frontseitiger Drehtür abschließbar und innerer Edelstahlverkleidung. Mit eingestellten Edelstahl-Abfallbehälter. Der Abfallbehälter ist in das Abluftsystem des Abzugs einzubinden, so dass beim Abwurf freigesetzte Aktivitäten über das zentrale Filtersystem geführt und zurückgehalten werden, bevor sie in das externe Abluftsystem gelangen können. Innenabmessungen Abfallbehälter: - ca. 350 x 350 x 350 mm (B x T x H). Für die innere Abwurföffnung (d=150 mm) ist ein abnehmbarer Edelstahldeckel mit 20 mm Blei im Abzug auszuführen. Weiterhin ist ein Einsatz mit Deckel zu liefern mit dem der Durchmesser des Abwurfs auf 70–75 mm verkleinert werden kann, so dass die Arbeitsfläche vergrößert werden kann."
#     },
#     {
#       "variant_no": "01.02.0002",
#       "title": "Abzug Abfallbehälter 50mm Pb",
#       "page_from": 57,
#       "page_to": 57,
#       "text": "Erweiterte Ausstattung abgeschirmte Abfallbehälter für Radionuklidabzug. Fest eingebauter Abfallbehälter mit 50 mm Bleiabschirmung unterhalb des Abzugs (Abwurfprinzip). Die Abfalleinheit ist statisch unabhängig von dem Abzug untergebaut, damit diese bei Bedarf gegen eine größere Einheit ausgetauscht werden kann. Eine Einschränkung durch Verblendungen darf nicht gegeben sein. Diese müssen zum Ausbau der Abfalleinheit leicht demontierbar sein. Unterbaustahlschrank, mit frontseitiger Drehtür abschließbar und innerer Edelstahlverkleidung. Mit eingestellten Edelstahl-Abfallbehälter. Der Abfallbehälter ist in das Abluftsystem des Abzugs einzubinden, so dass beim Abwurf freigesetzte Aktivitäten über das zentrale Filtersystem geführt und zurückgehalten werden, bevor sie in das externe Abluftsystem gelangen können. Innenabmessungen Abfallbehälter: - ca. 350 x 350 x 350 mm (B x T x H). Für die innere Abwurföffnung (d=150 mm) ist ein abnehmbarer Edelstahldeckel mit 50 mm Blei im Abzug auszuführen. Weiterhin ist ein Einsatz mit Deckel zu liefern mit dem der Durchmesser des Abwurfs auf 70–75 mm verkleinert werden kann, so dass die Arbeitsfläche vergrößert werden kann."
#     },
#     {
#       "variant_no": "01.02.0003",
#       "title": "Aktivimeter - 20mm Pb Abschirmung",
#       "page_from": 58,
#       "page_to": 59,
#       "text": "Erweiterte Ausstattung abgeschirmte Sicherheitswerkbank oder strahlengeschützer Abzug: Aktivimeter. Zur PC-basierten Bestimmung der Aktivität in üblichen in der Nuklear Medizin, Radiochemie und Radiopharmazie eingesetzten Arbeitsmitteln (Spritzen, Nadeln, Vials, etc.). Bestehend aus: - Ionisationskammer - Ionisationskammerlift - Dosiskalibriersystem - Geräteträgerarm. Ionisationskammer 20 mm Pb-Abschirmung: Abgeschirmte Ionisationskammer mit 20 mm Bleiabschirmung. - als Schacht-Ionisationskammer mit 4 mm Bleiabschirmung mit Aufnahme-Platte - Probenhalter für o.g. Materialien - Signalverstärker - Verbindung mittels USB-Interface - Bedienerhandbuch. Ionisationskammerlift: Baueinheit zur Aufnahme der Ionisationskammer mit der Messprobe. Liftfunktion: elektrisch oder pneumatisch betrieben, um die Messprobe in den Messraum der Ionisationskammer abzusenken. Dosiskalibriersystem: Systemanforderungen: - Betriebssystem: Microsoft Windows 10 Professional 64 Bit - CPU: Intel Core I7 - Arbeitsspeicher: Mindestens 4 GB - Maus und Keyboard - 2x USB-Anschluss - Festplatte: Mindestens 0,5 TB Festplatten-Speicherplatz - Grafikkarte: mindestens 1 GB dedizierten Grafikkartenspeicher - Netzwerkkarte: 1 GB Ethernet-PC - Bildschirm: 15\" Flat Screen - Spezialsoftware: - Nuklidbibliothek inkl. Daten für die Messung von ß-Strahlern - Qualitätssicherung nach DIN 6855-11 - Verwaltung der Probandendaten inkl. Bibliothek. In den Einheitspreis sind folgende Punkte mit einzukalkulieren: - Aufstellung, Einrichtung, Installation, Konfiguration des PCs und der Anwendersoftware - Mithilfe der Integration des PCs in die Domäne des Auftraggebers. Geräteträgerarm: Trägerarm zur Aufnahme eines Touch-screen PC oder einer Ionisationskammer Kontrolleinheit. PC-Einheit: mind. 15-Zoll. Tragfähigkeit: mind. 20 kg. Drehbarkeit: - Arm: 180° - Trägerelement: 180°. Horizontal Schwenkbarkeit: 280 mm. Befestigung: Von vorne an der Seitenwand. Länge: ca. 60 cm. Mitzuliefern sind: Alle benötigten Teile zum Anschluss an die Sicherheitswerkbank oder den Abzug. Alle benötigten Teile zum Anschluss an die bauseitigen Versorgungsanschlüsse. Anlieferung, Aufstellung, Montage, Inbetriebnahme mit allen Anschlüssen, Funktionsprüfung und Einweisung."
#     },
#     {
#       "variant_no": "01.02.0004",
#       "title": "Aktivimeter - 50mm Pb Abschirmung",
#       "page_from": 60,
#       "page_to": 61,
#       "text": "Erweiterte Ausstattung abgeschirmte Sicherheitswerkbank oder strahlengeschützer Abzug: Aktivimeter. Zur PC-basierten Bestimmung der Aktivität in üblichen in der Nuklear Medizin, Radiochemie und Radiopharmazie eingesetzten Arbeitsmitteln (Spritzen, Nadeln, Vials, etc.). Bestehend aus: - Ionisationskammer - Ionisationskammerlift - Dosiskalibriersystem - Geräteträgerarm. Ionisationskammer 50 mm Pb-Abschirmung: Abgeschirmte Ionisationskammer mit 50 mm Bleiabschirmung. - als Schacht-Ionisationskammer mit 4 mm Bleiabschirmung mit Aufnahme-Platte - Probenhalter für o.g. Materialien - Signalverstärker - Verbindung mittels USB-Interface - Bedienerhandbuch. Ionisationskammerlift: Baueinheit zur Aufnahme der Ionisationskammer mit der Messprobe. Liftfunktion: elektrisch oder pneumatisch betrieben, um die Messprobe in den Messraum der Ionisationskammer abzusenken. Dosiskalibriersystem: Systemanforderungen: - Betriebssystem: Microsoft Windows 10 Professional 64 Bit - CPU: Intel Core I7 - Arbeitsspeicher: Mindestens 4 GB - Maus und Keyboard - 2x USB-Anschluss - Festplatte: Mindestens 0,5 TB Festplatten-Speicherplatz - Grafikkarte: mindestens 1 GB dedizierten Grafikkartenspeicher - Netzwerkkarte: 1 GB Ethernet-PC - Bildschirm: 15\" Flat Screen - Spezialsoftware: - Nuklidbibliothek inkl. Daten für die Messung von ß-Strahlern - Qualitätssicherung nach DIN 6855-11 - Verwaltung der Probandendaten inkl. Bibliothek. In den Einheitspreis sind folgende Punkte mit einzukalkulieren: - Aufstellung, Einrichtung, Installation, Konfiguration des PCs und der Anwendersoftware - Mithilfe der Integration des PCs in die Domäne des Auftraggebers. Geräteträgerarm: Trägerarm zur Aufnahme eines Touch-screen PC oder einer Ionisationskammer Kontrolleinheit. PC-Einheit: mind. 15-Zoll. Tragfähigkeit: mind. 20 kg. Drehbarkeit: - Arm: 180° - Trägerelement: 180°. Horizontal Schwenkbarkeit: 280 mm. Befestigung: Von vorne an der Seitenwand. Länge: ca. 60 cm. Mitzuliefern sind: Alle benötigten Teile zum Anschluss an die Sicherheitswerkbank oder den Abzug. Alle benötigten Teile zum Anschluss an die bauseitigen Versorgungsanschlüsse. Anlieferung, Aufstellung, Montage, Inbetriebnahme mit allen Anschlüssen, Funktionsprüfung und Einweisung."
#     },
#     {
#       "variant_no": "01.02.0005",
#       "title": "Strahlenschutztechnischer Abzug 150 - 50mm Pb",
#       "page_from": 61,
#       "page_to": 64,
#       "text": "Abgeschirmter Radionuklidabzug auf Basis der EN 25466 für Produkt-, Umgebungs- und Personenschutz. Dimensionen: BxTxH in cm - Außenmaße: max. 165 x 100 x 275 - Innenmaße: min. 145 x 60 x 115 - Medienblende seitlich, rechts oder links: 15 cm breit. Das Gesamtbaumaß von 165 cm in der Breite darf nicht überschritten werden. Die Bauhöhe von 250 cm in der Höhe ist als Richtmaß zu sehen, dass garantiert zur Verfügung steht und wenn möglich eingehalten werden sollte. Arbeitsbereich/Kabine auf Untergestell aufgestellt. - Untergestell: aus Stahlrohr, nivellierbar. Untergestell ausgelegt auf die Last mit Lastverteilplatten die aber nicht über die Außenkanten der Baueinheit hinaus ragen dürfen (max. 30 x 30 cm) - Gehäuse: Außen - Stahlblech beschichtet, Farbe gemäß Vorbemerkung - Innenbereich: fugenfrei Polypropylen - Arbeitsfläche: Polypropylen mit umlaufendem Wulstrand, nicht segmentierte Arbeitsplatte, leicht herausnehmbar - Höhe der Arbeitsfläche: als Stehtisch mit mindestens 90 cm - Untergestell so ausgeführt, dass die beschriebenen Ein
antriebs einer bauseitigen CAV/VAV-Klappe (fester Anschluss durch Dritte). Direkte Einbindung der Abluft in das Abluftsystem. Übergangselement für den internen Abluftkanal auf einen runden Kanal DN250 mit Flansch. - Standby-Modus/Absenkbetrieb. Sicherheitseinrichtungen: Funktionsanzeige zur Anzeige des Betriebszustandes des Abzugs: - Betriebsbereit - Nachtbetrieb = abgesenkter Betrieb - Störung. Der Abzug wird unabhängig von der Frontschieberstellung mit einem konstanten Abluftvolumenstrom betrieben. Eine Absenkung des Volumenstroms erfolgt nur im Rahmen der Nachtabsenkung. Die Funktionsanzeige muss mit einer optischen und akustischen Alarmfunktion ausgestattet sein. Beleuchtung: - Beleuchtungssatz mit LED-Leuchte in der Decke. Leistung analog etwa 2 x 36 W Leuchtstoffröhre - Farbe: Weiß, 4.000 K - Dimmbar - Wechsel der Leuchtmittel von außerhalb der Arbeitskammer - Leuchtstärke auf der Arbeitsfläche min. 500 Lux - Beleuchtung unabhängig vom Betrieb der Lüftung schaltbar - Beleuchtung batteriegepuffert, damit bei Stromausfall ein geregeltes Herunterfahren der Experimente möglich ist. Ausstattung: - 4 Steckdosen 230 V (mind. IP44) im Arbeitsraum, von außen schaltbar - 3 x Reinstgasarmatur in 5.0 Qualität im Innenraum, von vorne von außen bedienbar - 1 x EDV-Doppeldose - 1 x Steckdose für Störmeldung. Die Durchgangsarmaturen werden durch den AN-Labormöbel zur Verfüg ...
#     },
#     {
#       "variant_no": "01.02.0007",
#       "title": "Leistungsprüfung Abzüge - Abluftmessung",
#       "page_from": 67,
#       "page_to": 67,
#       "text": "Die eingebaute Funktionseinheit aus Abzug, Volumenstromregler und der Funktionsanzeige ist vor dem Probebetrieb einzuregulieren und gemäß EN 14175-4 Absatz 5.5 zu überprüfen. Dies ist durch Messprotokolle zu dokumentieren, die vor dem Probebetrieb vorzulegen sind. Durchführung: Messung des Volumenstroms durch die Messung der Einströmgeschwindigkeit in der Prüf-Frontschieberöffnung gemäß EN 14175-4 Absatz 5.5.2. Die Messung erfolgt jeweils bei geschlossenem Frontschieber und bei Frontschieber in Arbeitshöhe sowie in enger Zusammenarbeit mit dem AN Lüftung."
#     },
#     {
#       "variant_no": "01.02.0008",
#       "title": "Leistungsprüfung Abzüge - Druckverlust",
#       "page_from": 67,
#       "page_to": 67,
#       "text": "Die eingebaute Funktionseinheit aus Abzug, Volumenstromregler und der Funktionsanzeige ist vor dem Probebetrieb einzuregulieren und gemäß DIN EN 14175-4 Absatz 5.6 zu überprüfen. Dies ist durch Messprotokolle zu dokumentieren, die vor dem Probebetrieb vorzulegen sind. Durchführung: Messung des Kanalvordrucks vor dem Volumenstromregler (entgegen DIN EN 14175-4) vereinfacht nur mit 1 Messstelle bei einer Frontschieberstellung Höhe 500 mm +/- 1%. Der durchschnittliche Druckverlust ist über eine Zeitspanne von mind. 60 sec. zu messen."
#     },
#     {
#       "variant_no": "01.02.0009",
#       "title": "Vor-Ort-Messung eines Abzuges",
#       "page_from": 68,
#       "page_to": 68,
#       "text": "Vor-Ort-Messung eines Abzuges bei der Inbetriebnahme nach EN 14175-4: 2004 mit allen Prüfungen durch ein unabhängiges Institut (inkl. Nachweis zur Befähigung). Die Messungen sind in Zusammenarbeit zwischen dem AN-Labortechnik und dem AN-Lüftungstechnik durchzuführen. Messergebnisse: Auswertung und Darstellung gemäß den Normvorgaben. Der zu messende Abzug wird durch den AG rechtzeitig zur Inbetriebnahme definiert."
#     },
#     {
#       "variant_no": "01.02.0010",
#       "title": "Abzug 120",
#       "page_from": 68,
#       "page_to": 69,
#       "text": "Gemäß EN 14 175, bestehend aus: Stahltragegestell, Medienzelle, Oberteil mit Abluftanschluss, separate Unterbauabsaugung, Beleuchtung, mind. 6 Stativhalterungen an der Rückwand und Mediendurchführungen in den Seitenwänden. Linke Seitenwand fest, rechte Seitenwand verglast. Tischabdeckung: großflächiges Steinzeug mit umlaufendem Wulstrand. Die Elektro-Steckdosen werden an der Rückwand des Abzugs angebracht und sind von außen über ein Schaltfeld einzeln schaltbar. Eine 230 V Steckdose ist außen angebracht. Frontseite: Armaturenzarge mit Elektro-Bestückung: 1 Steckdose 230 V (16 A) im Bedienfeld, 5 Schalter für 230 V Steckdosen, 5 Steckdosen 230 V (16 A) in der Rückwand des Abzugs, 1 Schalter für Beleuchtung, 1 lufttechnische Überwachungseinheit mit optischer und akustischer Anzeige. Sanitär-Bestückung: 1 Reinstgas-Entnahme-Armatur Messing. Anschluss an Potentialausgleich. Abmessungen: 120 x ca. 90 x 90 / 275 cm (B x T x H)."
#     },
#     {
#       "variant_no": "01.02.0011",
#       "title": "Abzug 150",
#       "page_from": 69,
#       "page_to": 70,
#       "text": "Gemäß EN 14 175, bestehend aus: Stahltragegestell, Medienzelle, Oberteil mit Abluftanschluss, separate Unterbauabsaugung, Beleuchtung, mind. 9 Stativhalterungen an der Rückwand und Mediendurchführungen in den Seitenwänden. Linke Seitenwand fest, rechte Seitenwand verglast. Tischabdeckung: Polypropylen mit umlaufendem Wulstrand. Die Elektro-Steckdosen werden an der Rückwand des Abzugs angebracht und sind von außen über ein Schaltfeld einzeln schaltbar. Eine 230 V Steckdose ist außen angebracht. Frontseite: Armaturenzarge mit Elektro-Bestückung: 1 Steckdose 230 V (16 A) im Bedienfeld, 5 Schalter für 230 V Steckdosen, 5 Steckdosen 230 V (16 A) in der Rückwand des Abzugs, 1 Schalter für Beleuchtung, 1 lufttechnische Überwachungseinheit mit optischer und akustischer Anzeige, 1 Hohlwanddose für EDV, Telefon oder MSR im Bedienfeld. Sanitär-Bestückung: 2 Reinstgas-Entnahme-Armaturen Messing, 1 Kühlwasser-Entnahme-Armatur, 1 Vakuum-Entnahme-Armatur. Anschluss an Potentialausgleich. Abmessungen: 150 x ca. 90 x 90 / 275 cm (B x T x H)."
#     },
#     {
#       "variant_no": "01.02.0012",
#       "title": "Abzug 150",
#       "page_from": 70,
#       "page_to": 71,
#       "text": "Gemäß EN 14 175, bestehend aus: Stahltragegestell, Medienzelle, Oberteil mit Abluftanschluss, separate Unterbauabsaugung, Beleuchtung, mind. 9 Stativhalterungen an der Rückwand und Mediendurchführungen in den Seitenwänden. Beide Seitenwände fest. Tischabdeckung: großflächiges Steinzeug mit umlaufendem Wulstrand. Die Elektro-Steckdosen werden an der Rückwand des Abzugs angebracht und sind von außen über ein Schaltfeld einzeln schaltbar. Eine 230 V Steckdose ist außen angebracht. Frontseite: Armaturenzarge mit Elektro-Bestückung: 1 Steckdose 230 V (16 A) im Bedienfeld, 5 Schalter für 230 V Steckdosen, 5 Steckdosen 230 V (16 A) in der Rückwand des Abzugs, 1 Schalter für Beleuchtung, 1 lufttechnische Überwachungseinheit mit optischer und akustischer Anzeige. Anschluss an Potentialausgleich. Abmessungen: 150 x ca. 90 x 90 / 275 cm (B x T x H)."
#     },
#     {
#       "variant_no": "01.02.0013",
#       "title": "Abzug 150",
#       "page_from": 71,
#       "page_to": 71,
#       "text": "Gemäß EN 14 175, bestehend aus: Stahltragegestell, Medienzelle, Oberteil mit Abluftanschluss, separate Unterbauabsaugung, Beleuchtung, mind. 9 Stativhalterungen an der Rückwand und Mediendurchführungen in den Seitenwänden. Beide Seitenwände fest. Tischabdeckung: großflächiges Steinzeug mit umlaufendem Wulstrand. Die Elektro-Steckdosen werden an der Rückwand des Abzugs angebracht und sind von außen über ein Schaltfeld einzeln schaltbar. Eine 230 V Steckdose ist außen angebracht. Frontseite: Armaturenzarge mit Elektro-Bestückung: 1 Steckdose 230 V (16 A) im Bedienfeld, 5 Schalter für 230 V Steckdosen, 5 Steckdosen 230 V (16 A) in der Rückwand des Abzugs, 1 Schalter für Beleuchtung, 1 lufttechnische Überwachungseinheit mit optischer und akustischer Anzeige, 1 Hohlwanddose für EDV, Telefon oder MSR im Bedienfeld. Sanitär-Bestückung: 2 Reinstgas-Entnahme-Armaturen Messing, 1 Kühlwasser-Entnahme-Armatur, 1 Vakuum-Entnahme-Armatur. Anschluss an Potentialausgleich. Abmessungen: 150 x ca. 90 x 90 / 275 cm (B x T x H)."
#     },
#     {
#       "variant_no": "01.02.0014",
#       "title": "Abzug 150",
#       "page_from": 71,
#       "page_to": 72,
#       "text": "Gemäß EN 14 175, bestehend aus: Stahltragegestell, Medienzelle, Oberteil mit Abluftanschluss, separate Unterbauabsaugung, Beleuchtung, mind. 9 Stativhalterungen an der Rückwand und Mediendurchführungen in den Seitenwänden. Beide Seitenwände fest. Tischabdeckung: großflächiges Steinzeug mit umlaufendem Wulstrand. Die Elektro-Steckdosen werden an der Rückwand des Abzugs angebracht und sind von außen über ein Schaltfeld einzeln schaltbar. Eine 230 V Steckdose ist außen angebracht. Frontseite: Armaturenzarge mit Elektro-Bestückung: 1 Steckdose 230 V (16 A) im Bedienfeld, 5 Schalter für 230 V Steckdosen, 5 Steckdosen 230 V (16 A) in der Rückwand des Abzugs, 1 Schalter für Beleuchtung, 1 lufttechnische Überwachungseinheit mit optischer und akustischer Anzeige, 1 Hohlwanddose für EDV, Telefon oder MSR im Bedienfeld. Sanitär-Bestückung: 4 Reinstgas-Entnahme-Armaturen Messing, 1 Kühlwasser-Entnahme-Armatur, 1 Vakuum-Entnahme-Armatur. Anschluss an Potentialausgleich. Abmessungen: 150 x ca. 90 x 90 / 275 cm (B x T x H)."
#     },
#     {
#       "variant_no": "01.02.0015",
#       "title": "Abzug 150",
#       "page_from": 72,
#       "page_to": 73,
#       "text": "Gemäß EN 14 175, bestehend aus: Stahltragegestell, Medienzelle, Oberteil mit Abluftanschluss, separate Unterbauabsaugung, Beleuchtung, mind. 9 Stativhalterungen an der Rückwand und Mediendurchführungen in den Seitenwänden. Beide Seitenwände fest. Tischabdeckung: großflächiges Steinzeug mit umlaufendem Wulstrand. Die Elektro-Steckdosen werden an der Rückwand des Abzugs angebracht und sind von außen über ein Schaltfeld einzeln schaltbar. Eine 230 V Steckdose ist außen angebracht. Frontseite: Armaturenzarge mit Elektro-Bestückung: 1 Steckdose 230 V (16 A) im Bedienfeld, 5 Schalter für 230 V Steckdosen, 5 Steckdosen 230 V (16 A) in der Rückwand des Abzugs, 1 Schalter für Beleuchtung, 1 lufttechnische Überwachungseinheit mit optischer und akustischer Anzeige, 1 Hohlwanddose für EDV, Telefon oder MSR im Bedienfeld. Sanitär-Bestückung: 5 Reinstgas-Entnahme-Armaturen Messing, 1 Kühlwasser-Entnahme-Armatur, 1 Vakuum-Entnahme-Armatur. Anschluss an Potentialausgleich. Abmessungen: 150 x ca. 90 x 90 / 275 cm (B x T x H)."
#     },
#     {
#       "variant_no": "01.02.0016",
#       "title": "Abzug 150",
#       "page_from": 73,
#       "page_to": 74,
#       "text": "Gemäß EN 14 175, bestehend aus: Stahltragegestell, Medienzelle, Oberteil mit Abluftanschluss, separate Unterbauabsaugung, Beleuchtung, mind. 9 Stativhalterungen an der Rückwand und Mediendurchführungen in den Seitenwänden. Rechte Seitenwand fest, linke Seitenwand verglast. Tischabdeckung: großflächiges Steinzeug mit umlaufendem Wulstrand. Die Elektro-Steckdosen werden an der Rückwand des Abzugs angebracht und sind von außen über ein Schaltfeld einzeln schaltbar. Eine 230 V Steckdose ist außen angebracht. Frontseite: Armaturenzarge mit Elektro-Bestückung: 1 Steckdose 230 V (16 A) im Bedienfeld, 5 Schalter für 230 V Steckdosen, 5 Steckdosen 230 V (16 A) in der Rückwand des Abzugs, 1 Schalter für Beleuchtung, 2 Unterbau-Steckdosen 230 V (16 A), 1 lufttechnische Überwachungseinheit mit optischer und akustischer Anzeige, 1 Hohlwanddose für EDV, Telefon oder MSR im Bedienfeld. Sanitär-Bestückung: 5 Reinstgas-Entnahme-Armaturen Messing, 1 Kühlwasser-Entnahme-Armatur, 1 Vakuum-Entnahme-Armatur. Anschluss an Potentialausgleich. Abmessungen: 150 x ca. 90 x 90 / 275 cm (B x T x H)."
#     },
#     {
#       "variant_no": "01.02.0017",
#       "title": "Abzug 150",
#       "page_from": 74,
#       "page_to": 75,
#       "text": "Gemäß EN 14 175, bestehend aus: Stahltragegestell, Medienzelle, Oberteil mit Abluftanschluss, separate Unterbauabsaugung, Beleuchtung, mind. 9 Stativhalterungen an der Rückwand und Mediendurchführungen in den Seitenwänden. Rechte Seitenwand fest, linke Seitenwand verglast. Tischabdeckung: großflächiges Steinzeug mit umlaufendem Wulstrand. Die Elektro-Steckdosen werden an der Rückwand des Abzugs angebracht und sind von außen über ein Schaltfeld einzeln schaltbar. Eine 230 V Steckdose ist außen angebracht. Frontseite: Armaturenzarge mit Elektro-Bestückung: 1 Steckdose 230 V (16 A) im Bedienfeld, 5 Schalter für 230 V Steckdosen, 5 Steckdosen 230 V (16 A) in der Rückwand des Abzugs, 1 Schalter für Beleuchtung, 1 lufttechnische Überwachungseinheit mit optischer und akustischer Anzeige, 1 Hohlwanddose für EDV, Telefon oder MSR im Bedienfeld. Sanitär-Bestückung: 5 Reinstgas-Entnahme-Armaturen Messing, 1 Kühlwasser-Entnahme-Armatur, 1 Vakuum-Entnahme-Armatur. Anschluss an Potentialausgleich. Abmessungen: 150 x ca. 90 x 90 / 275 cm (B x T x H)."
#     },
#     {
#       "variant_no": "01.02.0018",
#       "title": "Abzug 150",
#       "page_from": 75,
#       "page_to": 76,
#       "text": "Gemäß EN 14 175, bestehend aus: Stahltragegestell, Medienzelle, Oberteil mit Abluftanschluss, separate Unterbauabsaugung, Beleuchtung, mind. 9 Stativhalterungen an der Rückwand und Mediendurchführungen in den Seitenwänden. Linke Seitenwand fest, rechte Seitenwand verglast. Tischabdeckung: großflächiges Steinzeug mit umlaufendem Wulstrand. Die Elektro-Steckdosen werden an der Rückwand des Abzugs angebracht und sind von außen über ein Schaltfeld einzeln schaltbar. Eine 230 V Steckdose ist außen angebracht. Frontseite: Armaturenzarge mit Elektro-Bestückung: 1 Steckdose 230 V (16 A) im Bedienfeld, 5 Schalter für 230 V Steckdosen, 5 Steckdosen 230 V (16 A) in der Rückwand des Abzugs, 1 Schalter für Beleuchtung, 2 Unterbau-Steckdosen 230 V (16 A), 1 lufttechnische Überwachungseinheit mit optischer und akustischer Anzeige, 1 Hohlwanddose für EDV, Telefon oder MSR im Bedienfeld. Sanitär-Bestückung: 2 Reinstgas-Entnahme-Armaturen Messing, 1 Kühlwasser-Entnahme-Armatur, 1 Vakuum-Entnahme-Armatur. Anschluss an Potentialausgleich. Abmessungen: 150 x ca. 90 x 90 / 275 cm (B x T x H)."
#     },
#     {
#       "variant_no": "01.02.0019",
#       "title": "Abzug 150",
#       "page_from": 76,
#       "page_to": 77,
#       "text": "Gemäß EN 14 175, bestehend aus: Stahltragegestell, Medienzelle, Oberteil mit Abluftanschluss, separate Unterbauabsaugung, Beleuchtung, mind. 9 Stativhalterungen an der Rückwand und Mediendurchführungen in den Seitenwänden. Linke Seitenwand fest, rechte Seitenwand verglast. Tischabdeckung: großflächiges Steinzeug mit umlaufendem Wulstrand. Die Elektro-Steckdosen werden an der Rückwand des Abzugs angebracht und sind von außen über ein Schaltfeld einzeln schaltbar. Eine 230 V Steckdose ist außen angebracht. Frontseite: Armaturenzarge mit Elektro-Bestückung: 1 Steckdose 230 V (16 A) im Bedienfeld, 5 Schalter für 230 V Steckdosen, 5 Steckdosen 230 V (16 A) in der Rückwand des Abzugs, 1 Schalter für Beleuchtung, 1 lufttechnische Überwachungseinheit mit optischer und akustischer Anzeige, 1 Hohlwanddose für EDV, Telefon oder MSR im Bedienfeld. Sanitär-Bestückung: 2 Reinstgas-Entnahme-Armaturen Messing, 1 Kühlwasser-Entnahme-Armatur, 1 Vakuum-Entnahme-Armatur. Anschluss an Potentialausgleich. Abmessungen: 150 x ca. 90 x 90 / 275 cm (B x T x H)."
#     },
#     {
#       "variant_no": "01.02.0020",
#       "title": "Abzug-Schiebefenster-Controller",
#       "page_from": 77,
#       "page_to": 77,
#       "text": "Der Schiebefenster-Controller schließt automatisch (motorisch) das Abzugsschiebefenster bei Nichtbenutzung des Abzugs. Bauteile: Prozessorgesteuerte Zentraleinheit mit integriertem Netzteil, Motorantrieb, sensorische Frontöffnungsüberwachung über zwei Sensorsysteme: Lichtschranke mit Stecker für Anschlusskabel, einer Optik und einem Potentiometer für Empfindlichkeitsabstimmung auf der Prozessorplatine, Bewegungsmelder zum Einbau ins Abzugoberteil. Einstellmöglichkeit der Schließverzögerung nach Freigabe der Sensoren zwischen 10 Sekunden und drei Minuten. Die Bedienbarkeit des Schiebefensters muss jederzeit und uneingeschränkt gegeben sein. Der Schiebefenster-Controller muss vollständig funktionsfähig in den entsprechenden Abzug eingebaut werden. Alle dafür notwendigen Materialien und Montagekosten sind in den Einzelpreis mit einzukalkulieren."
#     },
#     {
#       "variant_no": "01.02.0021",
#       "title": "Abzugs-Funktionsanzeige für variablen Betrieb",
#       "page_from": 77,
#       "page_to": 78,
#       "text": "Als Ersatz für die lufttechnische Überwachungsanzeige ist die nachfolgende Mess- und Regeleinrichtung für die variable Steuerung in die Abzüge einzubauen (siehe auch Vorbemerkungen Abzüge). Anzeige geeignet für den variablen Betrieb: Hierzu hat eine Sollwertermittlung über die Flächenwerte oder der Einströmgeschwindigkeit oder aus beiden zu erfolgen. Das Funktionsprinzip ist dem Angebot beizulegen. Abzüge-Regelung bestehend aus: Mikroprozessorgesteuerter Regler zum Betrieb des Abzugs mit variabler Steuerung wie im allgemeinen Leistungsbeschrieb der Abluftregelung beschrieben. Der Volumenstrom muss sich linear mit dem Frontschieber verändern. Der Volumenstrom muss sich den Seitenschiebern anpassen, z. B. Endkontakt. Vollständig geöffneter Frontschieber: Die maximalen Luftmengen gemäß Vorbemerkungen, bei definierten Rückhaltevermögen. Abluftmenge in Abhängigkeit von der Schiebefensterstellung mit folgenden Leistungsmerkmalen: Erkennung von Zuständen und Störungen mit Alarmierung (optisch, akustisch), Überwachung des bauseitigen Lüftungssystems, freie Programmierbarkeit, Nachtbetriebsfunktion, manuelle Rücksetzung auf Tagbetrieb muss möglich sein, Alarmmeldung als potentialfreier Schaltkontakt, Ausfallsicherheit durch Not-Akku bei Netzausfall. Ausgang Steuersignal für Abluftvolumenstromregler (0–10 V oder 2–10 V). Notwendige Bauteile für die Abzugregelung sind einschließlich Montagekosten in den Angebotseinzelpreis einzurechnen: Abluftsensor (Abzugfunktionsmessung), Frontschiebefenster-Sensor oder Einströmsensor, Seitenschiebefenster-Sensor falls notwendig, Kontrolltableau mit Prozessorelektronik, Not-Akku zur Stromversorgung bei Netzausfall, Ausgangsanschluss an den Gruppencontroller, Anschluss an den Abluftvolumenstromregler, Anschluss und Anschlusskabel an den Schiebefenstercontroller oder Einströmsensor, Ausgangsanschluss für den Sollwert des Volumenstromreglers (0–10 V oder 2–10 V). Des weiteren muss die Funktionsanzeigeeinheit geeignet sein, Sollvolumenströme für einen Zuluftregler zu liefern, unter der Berücksichtigung von anderen konstanten Abluftvolumenströmen. Stell- und Steuercharakteristik: Zur Aufrechterhaltung des Unterdruckes im Labor, bei Absenkung der Luftmenge, muss die Funktionsanzeigeeinheit geeignet sein, die Stellcharakteristik der bauseitigen Zuluftvolumenstromregler zu imitieren. Hierzu müssen die Stellgeschwindigkeiten dieser Regler hinterlegbar sein. Bei einer Alarmierung ist über einen Betätigungsknopf das akustische Signal quittierbar. Das optische Signal verlöscht nach Wiederherstellung der geforderten lüftungstechnischen Parameter selbsttätig. Es sind detaillierte Unterlagen über die technische Funktionsweise der kompletten Regel- und Steuereinheit auf Anforderung innerhalb von 6 Werktagen vorzulegen."
#     }
#   ]
# }

# %%
# Save the product variants
with open('data/product_variants.json', 'w') as f:
    f.write(group_1_variants)

# %% [markdown]
# ## Extract the required Components from the Product Group

# %%
def get_required_components_prompt(prod_group_nr, prod_group_title):
    json_schema = """
    {
    "type": "object",
    "properties": {
        "components": {
            "type": "array",
            "items": {
                "type": "object",
                "properties": {
                    "component_description": { "type": "string" },
                    "variant_nos": { "type": "array", "items": { "type": "string" } }
                },
                "required": ["component_description", "variant_nos"]
            }
        }
    }
    """

    variants = json.load(open('data/product_variants.json'))
    variants = variants["variants"]
    variants_str = "\n".join([f"{v['variant_no']}: {v['title']} text: {v['text']}" for v in variants])


    return f"""
    Task: Extract the required components for the product group {prod_group_nr} {prod_group_title} from the German LV-Liste text. 
    The components are the parts that are required to assemble the product. Severals variants can require the same component. 
    Output: Return only JSON that matches the schema below—no prose.

    Input format: You will receive the product variants for the product group from a PDF (German) with the necessary information.

    Your job:
    1.	Find the required components.
    2.	Extract the title, page range, and text for each required component.
    3.	Normalize trivial whitespace; keep German umlauts.

    Return only JSON matching the schema below.

    {json_schema}

    Product variants:
    {variants_str}
    """
    
def get_required_components(prod_group_nr, prod_group_title, page_from, page_to, page_offset, texts, client):
    prompt = get_required_components_prompt(prod_group_nr, prod_group_title)
    response = client.responses.create(
        model="gpt-5",
        input=prompt
    )
    return response.output_text

group_1_required_components = get_required_components(group_1["group_no"], group_1["title"], group_1["page_from"], group_1["page_to"], page_offset, texts, client)
print(group_1_required_components)
# Out:
# {
#   "components": [
#     {
#       "component_description": "Unterbaustahlschrank, frontseitig abschließbare Drehtür, innere Edelstahlverkleidung, statisch unabhängig untergebaut",
#       "variant_nos": ["01.02.0001", "01.02.0002"]
#     },
#     {
#       "component_description": "Edelstahl-Abfallbehälter ca. 350 x 350 x 350 mm, in das Abluftsystem des Abzugs einzubinden",
#       "variant_nos": ["01.02.0001", "01.02.0002"]
#     },
#     {
#       "component_description": "Abnehmbarer Edelstahldeckel für Abwurföffnung d=150 mm mit 20 mm Blei",
#       "variant_nos": ["01.02.0001"]
#     },
#     {
#       "component_description": "Abnehmbarer Edelstahldeckel für Abwurföffnung d=150 mm mit 50 mm Blei",
#       "variant_nos": ["01.02.0002"]
#     },
#     {
#       "component_description": "Einsatz mit Deckel zur Verkleinerung des Abwurfs auf 70–75 mm",
#       "variant_nos": ["01.02.0001", "01.02.0002"]
#     },
#     {
#       "component_description": "Abgeschirmte Durchführung zur Abfalleinheit d=150 mm mit Deckel",
#       "variant_nos": ["01.02.0005", "01.02.0006"]
#     },
#     {
#       "component_description": "Abgeschirmte Ionisationskammer 20 mm Pb",
#       "variant_nos": ["01.02.0003"]
#     },
#     {
#       "component_description": "Abgeschirmte Ionisationskammer 50 mm Pb",
#       "variant_nos": ["01.02.0004"]
#     },
#     {
#       "component_description": "Probenhalter, Signalverstärker und USB-Interface für Ionisationskammer",
#       "variant_nos": ["01.02.0003", "01.02.0004"]
#     },
#     {
#       "component_description": "Ionisationskammerlift (elektrisch oder pneumatisch)",
#       "variant_nos": ["01.02.0003", "01.02.0004"]
#     },
#     {
#       "component_description": "Dosiskalibriersystem (PC mit Windows 10 Pro 64 Bit, Spezialsoftware inkl. Nuklidbibliothek, QS nach DIN 6855-11)",
#       "variant_nos": ["01.02.0003", "01.02.0004"]
#     },
#     {
#       "component_description": "Geräteträgerarm für Touchscreen-PC/Kontrolleinheit, mind. 15\", Tragfähigkeit mind. 20 kg, Länge ca. 60 cm, Befestigung seitlich",
#       "variant_nos": ["01.02.0003", "01.02.0004"]
#     },
#     {
#       "component_description": "Anschlussmaterialien und Montage/Inbetriebnahme für Aktivimeter an Werkbank/Abzug und bauseitige Versorgungen",
#       "variant_nos": ["01.02.0003", "01.02.0004"]
#     },
#     {
#       "component_description": "Stahluntergestell/Stahltragegestell, nivellierbar",
#       "variant_nos": ["01.02.0005", "01.02.0006", "01.02.0010", "01.02.0011", "01.02.0012", "01.02.0013", "01.02.0014", "01.02.0015", "01.02.0016", "01.02.0017", "01.02.0018", "01.02.0019"]
#     },
#     {
#       "component_description": "Gehäuse außen beschichtetes Stahlblech, Innenbereich fugenfrei Polypropylen",
#       "variant_nos": ["01.02.0005", "01.02.0006"]
#     },
#     {
#       "component_description": "Arbeitsfläche Polypropylen mit umlaufendem Wulstrand, nicht segmentiert, leicht herausnehmbar",
#       "variant_nos": ["01.02.0005", "01.02.0006", "01.02.0011"]
#     },
#     {
#       "component_description": "Tischabdeckung großflächiges Steinzeug mit umlaufendem Wulstrand",
#       "variant_nos": ["01.02.0010", "01.02.0012", "01.02.0013", "01.02.0014", "01.02.0015", "01.02.0016", "01.02.0017", "01.02.0018", "01.02.0019"]
#     },
#     {
#       "component_description": "Bleiabschirmung 20 mm allseitig (Seiten, Front, Rückwand, unterhalb Arbeitsfläche, Decke) mit Weiterführung auf Front/Seiten bis Gesamthöhe 50 mm",
#       "variant_nos": ["01.02.0005"]
#     },
#     {
#       "component_description": "Bleiabschirmung 50 mm allseitig (Seiten, Front, Rückwand, unterhalb Arbeitsfläche, Decke)",
#       "variant_nos": ["01.02.0006"]
#     },
#     {
#       "component_description": "Mobiles Strahlenschutzschild mit Fenster, 20 mm Pb; Bleiglas äquivalent 20 mm Pb",
#       "variant_nos": ["01.02.0005"]
#     },
#     {
#       "component_description": "Mobiles Strahlenschutzschild mit Fenster, 50 mm Pb; Bleiglas äquivalent 50 mm Pb",
#       "variant_nos": ["01.02.0006"]
#     },
#     {
#       "component_description": "Frontschieber aus 6 mm Sicherheitsglas mit 3/4 Querschiebern, elektrisch angetrieben",
#       "variant_nos": ["01.02.0005", "01.02.0006"]
#     },
#     {
#       "component_description": "Abluftübergang DN250 mit Flansch, Ein/Aus-Schalter mit 0–10 V Signal für CAV/VAV, Standby-/Nachtabsenkung",
#       "variant_nos": ["01.02.0005", "01.02.0006"]
#     },
#     {
#       "component_description": "Überwachungs-/Funktionsanzeige mit optischer und akustischer Alarmierung",
#       "variant_nos": ["01.02.0005", "01.02.0006", "01.02.0010", "01.02.0011", "01.02.0012", "01.02.0013", "01.02.0014", "01.02.0015", "01.02.0016", "01.02.0017", "01.02.0018", "01.02.0019"]
#     },
#     {
#       "component_description": "LED-Beleuchtung 4.000 K, dimmbar, ≥ 500 Lux, batteriegepuffert",
#       "variant_nos": ["01.02.0005", "01.02.0006"]
#     },
#     {
#       "component_description": "Beleuchtungseinheit im Abzug",
#       "variant_nos": ["01.02.0010", "01.02.0011", "01.02.0012", "01.02.0013", "01.02.0014", "01.02.0015", "01.02.0016", "01.02.0017", "01.02.0018", "01.02.0019"]
#     },
#     {
#       "component_description": "Elektroausstattung im Arbeitsraum: Steckdosen 230 V und Schaltfeld (innen von außen schaltbar)",
#       "variant_nos": ["01.02.0005", "01.02.0006", "01.02.0010", "01.02.0011", "01.02.0012", "01.02.0013", "01.02.0014", "01.02.0015", "01.02.0016", "01.02.0017", "01.02.0018", "01.02.0019"]
#     },
#     {
#       "component_description": "Außensteckdose 230 V",
#       "variant_nos": ["01.02.0010", "01.02.0011", "01.02.0012", "01.02.0013", "01.02.0014", "01.02.0015", "01.02.0016", "01.02.0017", "01.02.0018", "01.02.0019"]
#     },
#     {
#       "component_description": "EDV-Doppeldose",
#       "variant_nos": ["01.02.0005", "01.02.0006"]
#     },
#     {
#       "component_description": "Hohlwanddose für EDV/Telefon/MSR im Bedienfeld",
#       "variant_nos": ["01.02.0011", "01.02.0013", "01.02.0014", "01.02.0015", "01.02.0016", "01.02.0017", "01.02.0018", "01.02.0019"]
#     },
#     {
#       "component_description": "2 Unterbau-Steckdosen 230 V (16 A)",
#       "variant_nos": ["01.02.0016", "01.02.0018"]
#     },
#     {
#       "component_description": "Reinstgasarmaturen (Reinstgas 5.0)",
#       "variant_nos": ["01.02.0005", "01.02.0006", "01.02.0010", "01.02.0011", "01.02.0013", "01.02.0014", "01.02.0015", "01.02.0016", "01.02.0017", "01.02.0018", "01.02.0019"]
#     },
#     {
#       "component_description": "Kühlwasser-Entnahme-Armatur",
#       "variant_nos": ["01.02.0011", "01.02.0013", "01.02.0014", "01.02.0015", "01.02.0016", "01.02.0017", "01.02.0018", "01.02.0019"]
#     },
#     {
#       "component_description": "Vakuum-Entnahme-Armatur",
#       "variant_nos": ["01.02.0011", "01.02.0013", "01.02.0014", "01.02.0015", "01.02.0016", "01.02.0017", "01.02.0018", "01.02.0019"]
#     },
#     {
#       "component_description": "Armaturenzarge/Bedienfeld mit Steckdosen- und Lichtschaltern",
#       "variant_nos": ["01.02.0010", "01.02.0011", "01.02.0012", "01.02.0013", "01.02.0014", "01.02.0015", "01.02.0016", "01.02.0017", "01.02.0018", "01.02.0019"]
#     },
#     {
#       "component_description": "Seitliche Medienblende mit Rahmen und Edelstahl-Deckplatten, Einschraubleisten M5, bis Decke verblendet",
#       "variant_nos": ["01.02.0005", "01.02.0006"]
#     },
#     {
#       "component_description": "Stativhalterungen an der Rückwand",
#       "variant_nos": ["01.02.0010", "01.02.0011", "01.02.0012", "01.02.0013", "01.02.0014", "01.02.0015", "01.02.0016", "01.02.0017", "01.02.0018", "01.02.0019"]
#     },
#     {
#       "component_description": "Mediendurchführungen in den Seitenwänden",
#       "variant_nos": ["01.02.0010", "01.02.0011", "01.02.0012", "01.02.0013", "01.02.0014", "01.02.0015", "01.02.0016", "01.02.0017", "01.02.0018", "01.02.0019"]
#     },
#     {
#       "component_description": "Separate Unterbauabsaugung",
#       "variant_nos": ["01.02.0010", "01.02.0011", "01.02.0012", "01.02.0013", "01.02.0014", "01.02.0015", "01.02.0016", "01.02.0017", "01.02.0018", "01.02.0019"]
#     },
#     {
#       "component_description": "Verglaste Seitenwand rechts",
#       "variant_nos": ["01.02.0010", "01.02.0011", "01.02.0018", "01.02.0019"]
#     },
#     {
#       "component_description": "Verglaste Seitenwand links",
#       "variant_nos": ["01.02.0016", "01.02.0017"]
#     },
#     {
#       "component_description": "Anschluss an Potentialausgleich",
#       "variant_nos": ["01.02.0010", "01.02.0011", "01.02.0012", "01.02.0013", "01.02.0014", "01.02.0015", "01.02.0016", "01.02.0017", "01.02.0018", "01.02.0019"]
#     },
#     {
#       "component_description": "Schiebefenster-Controller (Zentraleinheit mit Netzteil, Motorantrieb, Lichtschranke, Bewegungsmelder, einstellbare Schließverzögerung)",
#       "variant_nos": ["01.02.0020"]
#     },
#     {
#       "component_description": "Abzugs-Funktionsanzeige/Regelung für variablen Betrieb (Regler, Abluftsensor, Schiebefenster-/Einströmsensoren, Kontrolltableau, Not-Akku, 0–10 V/2–10 V Schnittstellen)",
#       "variant_nos": ["01.02.0021"]
#     }
#   ]
# }

# %%
# Save the required components
with open('data/required_components.json', 'w') as f:
    f.write(group_1_required_components)
